# %%
data = [23,24,32,45,12,43,67,45,32,56,32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import pandas as pd
data1 = pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/Iris.csv")

# %%
data2 = pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/Titanic.csv")

# %%
data1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy = data.copy()

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %% [markdown]
# pandas
#
# numpy
#
# matplotlib and seaborn
#
# scipy
#
# statsmodel
#
# statistics

# %% [markdown]
# mean,median ,mode

# %%
import numpy as np
np.mean(data)
# Out:
# 37.36363636363637

# %%
np.median(data)
# Out:
# 32.0

# %%
np.mean(data1["SepalLengthCm"])
# Out:
# 5.843333333333334

# %%
np.mode(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 np.mode(data)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/__init__.py:311, in __getattr__(attr)
#     308     from .testing import Tester
#     309     return Tester
# --> 311 raise AttributeError("module {!r} has no attribute "
#     312                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %% [markdown]
# So, for this we have to use statistics library

# %%
import statistics

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
from scipy import stats as st
st.mode(data)
# Out:
# /tmp/ipykernel_2479/3794622683.py:2: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   st.mode(data)
# ModeResult(mode=array([32]), count=array([3]))

# %%
np.mean(data_copy)
# Out:
# 37.36363636363637

# %%
def mean(data):
    sum = 0
    for i in data:
        sum = sum + i
        
    mean = sum/len(data)
        
    return mean

# %%
mean(data)
# Out:
# 37.36363636363637

# %%
data_copy.append(150)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
data_copy2= data.copy()

# %%
data_copy2.append(75)

# %%
np.mean(data_copy2)
# Out:
# 40.5

# %%
np.mean(data_copy)
# Out:
# 46.75

# %%
np.median(data)
# Out:
# 32.0

# %%
np.median(data_copy2)
# Out:
# 37.5

# %% [markdown]
# median is used when the high outliers are present because it's effecting the mean

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
data_copy.pop()
# Out:
# 150

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
np.percentile(data_copy,[25])
# Out:
# array([28.])

# %% [markdown]
# q1,q2,q3,q4
#
# IQR = q3-q1
#
# lower_fence=q1-IQR(1.5)
#
# upper_fence=q1+IQR(1.5)

# %% [markdown]
# We can do like thius also together

# %%
np.percentile(data_copy,[25,50,75,100])
# Out:
# array([28., 32., 45., 67.])

# %%
data_copy.append(150)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
import seaborn as sns
sns.boxplot(data_copy)
# Out:
# <AxesSubplot: >

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
np.random.choice(data,size=4)#random sampling
# Out:
# array([45, 67, 45, 67])

# %% [markdown]
# Find out atleast 5 techniques of the sampling and implement it with the help of python
#
# keep it over the github
#
# post it in linkedin

# %% [markdown]
# if we want the sample then we have to like this

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data2.sample(n = 10)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 350          351         0       3             Odahl, Mr. Nils Martin    male
# 724          725         1       1      Chambers, Mr. Norman Campbell    male
# 378          379         0       3                Betros, Mr. Tannous    male
# 761          762         0       3     Nirva, Mr. Iisakki Antino Aijo    male
# 118          119         0       1           Baxter, Mr. Quigg Edmond    male
# 261          262         1       3  Asplund, Master. Edvin Rojj Felix    male
# 304          305         0       3  Williams, Mr. Howard Hugh "Harry"    male
# 418          419         0       2         Matthews, Mr. William John    male
# 457          458         1       1  Kenyon, Mrs. Frederick R (Marion)  female
# 872          873         0       1           Carlsson, Mr. Frans Olof    male
#
#       Age  SibSp  Parch            Ticket      Fare        Cabin Embarked
# ...

# %%
data.sample(n = 4)# it doesn't happened because it is in the list for thi we have to do (random.choice)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 data.sample(n = 4)
#
# AttributeError: 'list' object has no attribute 'sample'

# %%
np.var(data)#if we do without code only with library like this then it will give for full population
# Out:
# 226.23140495867773

# %%
#pythin code for variance

def variance(data):
    n = len(data)
    
    mean = sum(data)/n
    #variance
    deviation = [(x - mean) ** 2 for x in data]
    variance = sum(deviation)/(n-1)
    return variance

# %%
variance(data)
# Out:
# 248.8545454545455

# %%
import statistics
statistics.variance(data)#internally it is using n-1 for sampling poopulation and n is using for population
# Out:
# 248.85454545454544

# %%
def variance(data):
    n = len(data)
    
    mean = sum(data)/n
    #variance
    deviation = [(x - mean) ** 2 for x in data]
    variance = sum(deviation)/(n)#It is population variance
    return variance

# %%
variance(data)
# Out:
# 226.23140495867773

# %%
statistics.pvariance(data)#We have to write pvariance explicitely then it will give population variance otherwise it will give sample data
# Out:
# 226.23140495867767

# %%
np.std(data)
# Out:
# 15.040990823701666

# %%
import math 
math.sqrt(statistics.variance(data))
# Out:
# 15.775124261144361

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2 = data.copy()

# %%
len(data)
# Out:
# 11

# %%
len(data)-1
# Out:
# 10

# %% [markdown]
# ##corr and cov

# %%
import seaborn as sns
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.corr()
# Out:
# /tmp/ipykernel_2479/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.scatterplot(x = df['tip'],y =df['size'])
# Out:
# <AxesSubplot: xlabel='tip', ylabel='size'>

# %%
sns.scatterplot(x=df['tip'],y=df ['total_bill'])
# Out:
# <AxesSubplot: xlabel='tip', ylabel='total_bill'>

# %%
df.cov()
# Out:
# /tmp/ipykernel_2479/1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %% [markdown]
# PDF Probability Distribution Function

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy.pop()
# Out:
# 150

# %%
data_copy.append(289)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 289]

# %%
import seaborn as sns
sns.histplot(data,kde = True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.histplot(data_copy,kde = True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
data_copy2[0]=-10

# %%
data_copy2[1]=-75

# %%
data_copy2
# Out:
# [-10, -75, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2,kde = True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
data1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.histplot(data1["SepalLengthCm"],kde = True)
# Out:
# <AxesSubplot: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data1["SepalWidthCm"],kde = True)
# Out:
# <AxesSubplot: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(data1["PetalLengthCm"],kde = True)
# Out:
# <AxesSubplot: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(data1["PetalWidthCm"],kde = True)
# Out:
# <AxesSubplot: xlabel='PetalWidthCm', ylabel='Count'>

# %%
s = np.random.normal(0.5,0.2,1000)

# %%
sns.histplot(s,kde = True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
mu,sigma = 3.0,1.0
p = np.random.lognormal(mu,sigma,1000)

# %%
sns.histplot(p,kde = True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.histplot(np.log(p),kde = True)# We can convert lognormal to normal one like this
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

# %%
def plot_data(sample):
    plt.figure(figsize = (10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde = True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist = 'norm' ,plot = pylab)
    plt.show()

# %%
plot_data(data)

# %%
plot_data(data_copy)

# %%
plot_data(s)

# %%
plot_data(p)

# %%
plot_data(np.log(p))
